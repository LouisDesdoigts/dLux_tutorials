# %% [markdown]
# # Prebuilt components
#
# Use the notable telescope-like and instrument components supplied by dLux, inspect their fidelity and assumptions, customise their supported overrides, and compose a new prebuilt component from the general builders.
