# %% [markdown]
# # Vector-Zernike wavefront sensing
#
# Model a vector-Zernike wavefront sensor with polarisation and atmospheric phase structure, then infer phase and amplitude errors from its detector observations.
