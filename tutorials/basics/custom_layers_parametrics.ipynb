# %% [markdown]
# # Custom layers and parametrics
#
# Implement a custom monochromatic optical layer and a custom parametric type, compose them into a model, and inspect how their values resolve from context. Raise, update, share, and differentiate their Zodiax parameter paths while preserving the dLux vectorisation contract.
