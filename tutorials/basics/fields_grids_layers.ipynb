# %% [markdown]
# # Fields, grids, wavefronts, and layers
#
# Explore how sampled grids, fields, wavefronts, and optical layers interact. Follow a field through a system and implement a small custom layer using the monochromatic layer contract.
