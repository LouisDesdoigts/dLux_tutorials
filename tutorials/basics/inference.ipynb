# %% [markdown]
# # Inference and statistical workflows
#
# Use one compact dLux model to demonstrate Zodiax parameter handling, Optax and Optimistix optimisation, NumPyro and BlackJAX sampling, noisy observations, likelihoods, Jacobians, Hessians, and Fisher information.
